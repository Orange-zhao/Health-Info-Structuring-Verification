# %%
import json
import numpy as np
import time
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# %%
import os
import json
import time
from openai import OpenAI

client = OpenAI(
    api_key=" ", 
    base_url="https://"
)

# %% [markdown]
# # 输出所有数据

# %%
import json
import numpy as np
import time
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# --- Paths ---
AUTH_VECTORS_JSON = r"output_data/knowledge_with_embeddings.json"
SOCIAL_DATA_JSON = r"output_data/triplets_with_embeddings_ver4.json"
OUTPUT_FILE = r"newresult/triples_ver4_result1.json"

# --- Load Functions ---
def load_json_data(path):
    with open(path, 'r', encoding='utf-8') as f:
        return json.load(f)

print("Loading authoritative knowledge base...")
RAW_KB_VECTORS = load_json_data(AUTH_VECTORS_JSON)

# ===== Build KB Vector Matrix =====
kb_embeddings = []
kb_entities = []

for item in RAW_KB_VECTORS:
    vec = item.get("embedding")
    if vec:
        kb_embeddings.append(vec)
        kb_entities.append(item)

KB_MATRIX = np.array(kb_embeddings)
print("KB matrix shape:", KB_MATRIX.shape)

# --- Vector Retrieval (with subject match check) ---
def get_best_kb_match(target_vec, social_subject, threshold=0.6):
    if target_vec is None:
        return None, None

    target_vec_np = np.array(target_vec).reshape(1, -1)
    sims = cosine_similarity(target_vec_np, KB_MATRIX)[0]
    best_idx = np.argmax(sims)
    best_sim = sims[best_idx]
    best_match = kb_entities[best_idx]

    # Subject mismatch check: if no word overlaps, treat as retrieval failure
    kb_subject = best_match.get("subject", "").lower()
    social_subj = social_subject.lower()

    if not any(word in kb_subject for word in social_subj.split()):
        return None, float(best_sim)

    if best_sim >= threshold:
        return best_match, float(best_sim)

    return None, float(best_sim)

# --- LLM Verification Function ---
def verify_with_llm_and_kb(social_triplet, context_text, kb_evidence, similarity):
    s = social_triplet.get('subject', 'N/A')
    p = social_triplet.get('predicate', 'N/A')
    o = social_triplet.get('object', 'N/A')

    sim_value = similarity if similarity is not None else 0.0

    prompt = f"""
[Role] You are a senior AI Architect specializing in Knowledge Graph Alignment, focusing on the intersection of Symbolic Reasoning and Vector Space Analysis.
[Objective] Compare "Extracted Triples from Short Videos" with "Authoritative Medical Knowledge Base Triples" and determine factual correctness.

[Social Media Claim]
Subject: {s} | Predicate: {p} | Object: {o}

[Cosine Similarity Score] {sim_value:.4f}
[Semantic Alignment Rule] Cosine similarity >= 0.6 indicates semantic alignment,
accounting for medical synonyms (e.g., "Inject" -> "Administer", "Sugar control" -> "Glycemic management").

[Video Context] {context_text if context_text else "N/A"}
[Authoritative KB Evidence] {kb_evidence if kb_evidence else "No direct evidence found in KB."}

[Critical Evaluation Rules]
1. Perform entity normalization before matching.
Treat semantically equivalent medical terms as the same entity.
Examples:
- "type 2 diabetes" = "type ii diabetes mellitus"
- "t2d" = "type 2 diabetes"
Only disregard KB if the subject is clearly unrelated.

2. When evaluating correctness:
- First attempt to match with KB evidence (if semantic alignment exists).
- If no relevant KB evidence is found, use established medical knowledge for judgment.

3. Only mark False if:
- The claim contradicts strong medical consensus, OR
- The claim contradicts reliable evidence, OR
- The claim is medically implausible or unsupported.

4. The relation "associated with" can describe:
- presence of a property
- absence of a property
Examples:
- associated with insulin resistance
- associated with absence of autoantibodies

5. Only treat KB evidence as contradiction if it refers to the SAME attribute or concept.
   If the KB discusses a different attribute, it should NOT be used to reject the claim.

[Task]
1. Status: Classify as "True" or "False".
   - "True": Claim is medically correct, supported by KB evidence or general medical knowledge.
   - "False": Claim directly contradicts a matching KB entry, established medical facts, or is medically implausible.

2. Explanation: Provide a concise reason for your decision, referencing KB match quality explicitly.
   - If Cosine Similarity < 0.6, you MUST identify a Mismatch Reason from:
     * Granularity Mismatch: Triple is too broad or too specific compared to KB.
     * Contextual Shift: Colloquial/metaphorical language drifted in vector space.
     * Logical Inversion: Predicate direction is reversed or negated.
     * Entity Ambiguity: Entity has multiple meanings causing vector drift.
     * Fact Contradiction: Directly contradicts evidence-based medicine.

Return ONLY a JSON object in this exact format:
{{"status": "True" or "False", "explanation": "...", "mismatch_reason": "Category name or null"}}
"""

    try:
        response = client.chat.completions.create(
            model="deepseek-chat",
            messages=[
                {"role": "system", "content": "You are a professional medical knowledge graph verifier. Always return valid JSON only."},
                {"role": "user", "content": prompt}
            ],
            response_format={"type": "json_object"},
            temperature=0,
            top_p=1
        )
        return json.loads(response.choices[0].message.content)

    except Exception as e:
        return {"status": "Error", "explanation": str(e), "mismatch_reason": None}

# --- Main Program ---
def main():
    print("Loading social media data...")
    social_data = load_json_data(SOCIAL_DATA_JSON)
    print("Total records:", len(social_data))

    final_report = []
    total_triplets = 0
    true_count = 0

    # ===== Group by Video =====
    grouped = defaultdict(list)
    for row in social_data:
        source = f"Video_{row.get('source_row', 'unknown')}"
        grouped[source].append(row)

    print("Total videos:", len(grouped))

    # ===== Main Loop =====
    for i, (source, triplets) in enumerate(grouped.items()):
        print(f"Processing {i+1}/{len(grouped)}: {source}")

        verified_triplets = []
        video_true = 0
        video_total = 0

        for t in triplets:
            target_vec = t.get('embedding')

            # Pass subject into retrieval for match quality check
            kb_match, similarity = get_best_kb_match(target_vec, t.get('subject', ''))

            if kb_match:
                kb_evidence = (
                    f"Subject: {kb_match.get('subject')} | "
                    f"Predicate: {kb_match.get('predicate')} | "
                    f"Object: {kb_match.get('object')} | "
                    f"Similarity: {similarity:.4f}"
                )
            else:
                kb_evidence = None

            verification = verify_with_llm_and_kb(t, "", kb_evidence, similarity)

            # Remove embedding from output
            t_clean = {k: v for k, v in t.items() if k != 'embedding'}
            t_clean.update(verification)

            if kb_match:
                t_clean['kb_alignment_info'] = {
                    "kb_subject": kb_match.get("subject"),
                    "kb_predicate": kb_match.get("predicate"),
                    "kb_object": kb_match.get("object"),
                    "similarity_score": similarity
                }
            else:
                t_clean['kb_alignment_info'] = {
                    "kb_subject": None,
                    "kb_predicate": None,
                    "kb_object": None,
                    "similarity_score": similarity
                }

            video_total += 1
            total_triplets += 1
            if str(verification.get("status", "")).strip().lower() == "true":
                video_true += 1
                true_count += 1

            verified_triplets.append(t_clean)

        video_accuracy = round(video_true / video_total, 4) if video_total > 0 else 0.0

        final_report.append({
            "video_source": source,
            "video_accuracy": video_accuracy,
            "video_true_count": video_true,
            "video_total_count": video_total,
            "verification_results": verified_triplets
        })

        time.sleep(0.05)

    # ===== Overall Accuracy =====
    overall_accuracy = round(true_count / total_triplets, 4) if total_triplets > 0 else 0.0

    output = {
        "overall_summary": {
            "total_triplets": total_triplets,
            "true_count": true_count,
            "false_count": total_triplets - true_count,
            "overall_accuracy": overall_accuracy
        },
        "video_reports": final_report
    }

    with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
        json.dump(output, f, ensure_ascii=False, indent=2)

    print("\n===== Verification Complete =====")
    print(f"Total triplets:     {total_triplets}")
    print(f"True count:         {true_count}")
    print(f"False count:        {total_triplets - true_count}")
    print(f"Overall accuracy:   {overall_accuracy:.2%}")
    print(f"Output file:        {OUTPUT_FILE}")

if __name__ == "__main__":
    main()
# Out:
# Loading authoritative knowledge base...
# KB matrix shape: (4940, 768)
# Loading social media data...
# Total records: 2704
# Total videos: 304
# Processing 1/304: Video_0
# Processing 2/304: Video_1
# Processing 3/304: Video_2
# Processing 4/304: Video_3
# Processing 5/304: Video_4
# Processing 6/304: Video_5
# Processing 7/304: Video_6
# Processing 8/304: Video_7
# Processing 9/304: Video_8
# Processing 10/304: Video_9
# Processing 11/304: Video_10
# Processing 12/304: Video_11
# Processing 13/304: Video_12
# Processing 14/304: Video_13
# Processing 15/304: Video_14
# Processing 16/304: Video_15
# Processing 17/304: Video_16
# Processing 18/304: Video_17
# Processing 19/304: Video_18
# Processing 20/304: Video_19
# Processing 21/304: Video_20
# Processing 22/304: Video_21
# Processing 23/304: Video_22
# Processing 24/304: Video_23
# Processing 25/304: Video_24
# Processing 26/304: Video_25
# Processing 27/304: Video_26
# Processing 28/304: Video_27
# Processing 29/304: Video_28
# Processing 30/304: Video_29
# Processing 31/304: Video_30
# Processing 32/304: Video_31
# Processing 33/304: Video_32
# Processing 34/304: Video_33
# Processing 35/304: Video_34
# Processing 36/304: Video_35
# Processing 37/304: Video_36
# Processing 38/304: Video_37
# Processing 39/304: Video_38
# Processing 40/304: Video_39
# Processing 41/304: Video_40
# Processing 42/304: Video_41
# Processing 43/304: Video_42
# Processing 44/304: Video_43
# Processing 45/304: Video_44
# Processing 46/304: Video_45
# Processing 47/304: Video_46
# Processing 48/304: Video_47
# Processing 49/304: Video_48
# Processing 50/304: Video_49
# Processing 51/304: Video_50
# Processing 52/304: Video_51
# Processing 53/304: Video_52
# Processing 54/304: Video_53
# Processing 55/304: Video_54
# Processing 56/304: Video_55
# Processing 57/304: Video_56
# Processing 58/304: Video_57
# Processing 59/304: Video_58
# Processing 60/304: Video_59
# Processing 61/304: Video_60
# Processing 62/304: Video_61
# Processing 63/304: Video_62
# Processing 64/304: Video_63
# Processing 65/304: Video_64
# Processing 66/304: Video_65
# Processing 67/304: Video_66
# Processing 68/304: Video_67
# Processing 69/304: Video_68
# Processing 70/304: Video_69
# Processing 71/304: Video_70
# Processing 72/304: Video_71
# Processing 73/304: Video_72
# Processing 74/304: Video_73
# Processing 75/304: Video_74
# Processing 76/304: Video_75
# Processing 77/304: Video_76
# Processing 78/304: Video_77
# Processing 79/304: Video_78
# Processing 80/304: Video_79
# Processing 81/304: Video_80
# Processing 82/304: Video_81
# Processing 83/304: Video_82
# Processing 84/304: Video_83
# Processing 85/304: Video_84
# Processing 86/304: Video_85
# Processing 87/304: Video_86
# Processing 88/304: Video_87
# Processing 89/304: Video_88
# Processing 90/304: Video_89
# Processing 91/304: Video_90
# Processing 92/304: Video_91
# Processing 93/304: Video_92
# Processing 94/304: Video_93
# Processing 95/304: Video_94
# Processing 96/304: Video_96
# Processing 97/304: Video_97
# Processing 98/304: Video_98
# Processing 99/304: Video_99
# Processing 100/304: Video_101
# Processing 101/304: Video_103
# Processing 102/304: Video_104
# Processing 103/304: Video_106
# Processing 104/304: Video_107
# Processing 105/304: Video_108
# Processing 106/304: Video_109
# Processing 107/304: Video_110
# Processing 108/304: Video_111
# Processing 109/304: Video_112
# Processing 110/304: Video_113
# Processing 111/304: Video_114
# Processing 112/304: Video_115
# Processing 113/304: Video_117
# Processing 114/304: Video_118
# Processing 115/304: Video_120
# Processing 116/304: Video_121
# Processing 117/304: Video_122
# Processing 118/304: Video_123
# Processing 119/304: Video_124
# Processing 120/304: Video_125
# Processing 121/304: Video_126
# Processing 122/304: Video_127
# Processing 123/304: Video_128
# Processing 124/304: Video_129
# Processing 125/304: Video_130
# Processing 126/304: Video_132
# Processing 127/304: Video_133
# Processing 128/304: Video_134
# Processing 129/304: Video_135
# Processing 130/304: Video_136
# Processing 131/304: Video_137
# Processing 132/304: Video_138
# Processing 133/304: Video_139
# Processing 134/304: Video_140
# Processing 135/304: Video_141
# Processing 136/304: Video_142
# Processing 137/304: Video_143
# Processing 138/304: Video_144
# Processing 139/304: Video_145
# Processing 140/304: Video_147
# Processing 141/304: Video_148
# Processing 142/304: Video_149
# Processing 143/304: Video_150
# Processing 144/304: Video_151
# Processing 145/304: Video_152
# Processing 146/304: Video_154
# Processing 147/304: Video_155
# Processing 148/304: Video_157
# Processing 149/304: Video_158
# Processing 150/304: Video_159
# Processing 151/304: Video_160
# Processing 152/304: Video_161
# Processing 153/304: Video_162
# Processing 154/304: Video_163
# Processing 155/304: Video_164
# Processing 156/304: Video_165
# Processing 157/304: Video_166
# Processing 158/304: Video_167
# Processing 159/304: Video_168
# Processing 160/304: Video_169
# Processing 161/304: Video_171
# Processing 162/304: Video_172
# Processing 163/304: Video_173
# Processing 164/304: Video_174
# Processing 165/304: Video_175
# Processing 166/304: Video_176
# Processing 167/304: Video_179
# Processing 168/304: Video_180
# Processing 169/304: Video_181
# Processing 170/304: Video_182
# Processing 171/304: Video_183
# Processing 172/304: Video_184
# Processing 173/304: Video_185
# Processing 174/304: Video_186
# Processing 175/304: Video_187
# Processing 176/304: Video_188
# Processing 177/304: Video_192
# Processing 178/304: Video_194
# Processing 179/304: Video_195
# Processing 180/304: Video_196
# Processing 181/304: Video_197
# Processing 182/304: Video_198
# Processing 183/304: Video_199
# Processing 184/304: Video_200
# Processing 185/304: Video_202
# Processing 186/304: Video_203
# Processing 187/304: Video_205
# Processing 188/304: Video_206
# Processing 189/304: Video_207
# Processing 190/304: Video_208
# Processing 191/304: Video_209
# Processing 192/304: Video_210
# Processing 193/304: Video_212
# Processing 194/304: Video_213
# Processing 195/304: Video_214
# Processing 196/304: Video_215
# Processing 197/304: Video_216
# Processing 198/304: Video_217
# Processing 199/304: Video_218
# Processing 200/304: Video_219
# Processing 201/304: Video_220
# Processing 202/304: Video_221
# Processing 203/304: Video_222
# Processing 204/304: Video_223
# Processing 205/304: Video_224
# Processing 206/304: Video_225
# Processing 207/304: Video_226
# Processing 208/304: Video_227
# Processing 209/304: Video_228
# Processing 210/304: Video_229
# Processing 211/304: Video_230
# Processing 212/304: Video_232
# Processing 213/304: Video_233
# Processing 214/304: Video_234
# Processing 215/304: Video_235
# Processing 216/304: Video_236
# Processing 217/304: Video_237
# Processing 218/304: Video_238
# Processing 219/304: Video_239
# Processing 220/304: Video_240
# Processing 221/304: Video_241
# Processing 222/304: Video_242
# Processing 223/304: Video_243
# Processing 224/304: Video_245
# Processing 225/304: Video_246
# Processing 226/304: Video_248
# Processing 227/304: Video_249
# Processing 228/304: Video_250
# Processing 229/304: Video_251
# Processing 230/304: Video_252
# Processing 231/304: Video_253
# Processing 232/304: Video_254
# Processing 233/304: Video_255
# Processing 234/304: Video_256
# Processing 235/304: Video_257
# Processing 236/304: Video_258
# Processing 237/304: Video_259
# Processing 238/304: Video_260
# Processing 239/304: Video_261
# Processing 240/304: Video_262
# Processing 241/304: Video_263
# Processing 242/304: Video_264
# Processing 243/304: Video_265
# Processing 244/304: Video_266
# Processing 245/304: Video_267
# Processing 246/304: Video_268
# Processing 247/304: Video_269
# Processing 248/304: Video_270
# Processing 249/304: Video_273
# Processing 250/304: Video_274
# Processing 251/304: Video_275
# Processing 252/304: Video_276
# Processing 253/304: Video_278
# Processing 254/304: Video_279
# Processing 255/304: Video_280
# Processing 256/304: Video_281
# Processing 257/304: Video_282
# Processing 258/304: Video_283
# Processing 259/304: Video_284
# Processing 260/304: Video_285
# Processing 261/304: Video_286
# Processing 262/304: Video_287
# Processing 263/304: Video_288
# Processing 264/304: Video_289
# Processing 265/304: Video_290
# Processing 266/304: Video_291
# Processing 267/304: Video_292
# Processing 268/304: Video_293
# Processing 269/304: Video_294
# Processing 270/304: Video_295
# Processing 271/304: Video_296
# Processing 272/304: Video_297
# Processing 273/304: Video_298
# Processing 274/304: Video_299
# Processing 275/304: Video_300
# Processing 276/304: Video_301
# Processing 277/304: Video_302
# Processing 278/304: Video_303
# Processing 279/304: Video_304
# Processing 280/304: Video_305
# Processing 281/304: Video_306
# Processing 282/304: Video_307
# Processing 283/304: Video_308
# Processing 284/304: Video_309
# Processing 285/304: Video_310
# Processing 286/304: Video_311
# Processing 287/304: Video_312
# Processing 288/304: Video_313
# Processing 289/304: Video_314
# Processing 290/304: Video_315
# Processing 291/304: Video_316
# Processing 292/304: Video_317
# Processing 293/304: Video_318
# Processing 294/304: Video_319
# Processing 295/304: Video_320
# Processing 296/304: Video_321
# Processing 297/304: Video_322
# Processing 298/304: Video_323
# Processing 299/304: Video_324
# Processing 300/304: Video_325
# Processing 301/304: Video_326
# Processing 302/304: Video_327
# Processing 303/304: Video_328
# Processing 304/304: Video_329
#
# ===== Verification Complete =====
# Total triplets:     2704
# True count:         2032
# False count:        672
# Overall accuracy:   75.15%
# Output file:        newresults/triples_ver1_result2.json
