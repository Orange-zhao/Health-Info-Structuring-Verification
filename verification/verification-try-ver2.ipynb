# %%
import json
import numpy as np
import time
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# %%
import os
import json
import time
from openai import OpenAI

client = OpenAI(
    api_key=" ", 
    base_url="https://"
)

# %% [markdown]
# # 输出所有数据

# %%
import json
import numpy as np
import time
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# --- Paths ---
AUTH_VECTORS_JSON = r"output_data/knowledge_with_embeddings.json"
SOCIAL_DATA_JSON = r"output_data/triplets_with_embeddings_ver2.json"
OUTPUT_FILE = r"newresult/triples_ver2_result1.json"

# --- Load Functions ---
def load_json_data(path):
    with open(path, 'r', encoding='utf-8') as f:
        return json.load(f)

print("Loading authoritative knowledge base...")
RAW_KB_VECTORS = load_json_data(AUTH_VECTORS_JSON)

# ===== Build KB Vector Matrix =====
kb_embeddings = []
kb_entities = []

for item in RAW_KB_VECTORS:
    vec = item.get("embedding")
    if vec:
        kb_embeddings.append(vec)
        kb_entities.append(item)

KB_MATRIX = np.array(kb_embeddings)
print("KB matrix shape:", KB_MATRIX.shape)

# --- Vector Retrieval (with subject match check) ---
def get_best_kb_match(target_vec, social_subject, threshold=0.6):
    if target_vec is None:
        return None, None

    target_vec_np = np.array(target_vec).reshape(1, -1)
    sims = cosine_similarity(target_vec_np, KB_MATRIX)[0]
    best_idx = np.argmax(sims)
    best_sim = sims[best_idx]
    best_match = kb_entities[best_idx]

    # Subject mismatch check: if no word overlaps, treat as retrieval failure
    kb_subject = best_match.get("subject", "").lower()
    social_subj = social_subject.lower()

    if not any(word in kb_subject for word in social_subj.split()):
        return None, float(best_sim)

    if best_sim >= threshold:
        return best_match, float(best_sim)

    return None, float(best_sim)

# --- LLM Verification Function ---
def verify_with_llm_and_kb(social_triplet, context_text, kb_evidence, similarity):
    s = social_triplet.get('subject', 'N/A')
    p = social_triplet.get('predicate', 'N/A')
    o = social_triplet.get('object', 'N/A')

    sim_value = similarity if similarity is not None else 0.0

    prompt = f"""
[Role] You are a senior AI Architect specializing in Knowledge Graph Alignment, focusing on the intersection of Symbolic Reasoning and Vector Space Analysis.
[Objective] Compare "Extracted Triples from Short Videos" with "Authoritative Medical Knowledge Base Triples" and determine factual correctness.

[Social Media Claim]
Subject: {s} | Predicate: {p} | Object: {o}

[Cosine Similarity Score] {sim_value:.4f}
[Semantic Alignment Rule] Cosine similarity >= 0.6 indicates semantic alignment,
accounting for medical synonyms (e.g., "Inject" -> "Administer", "Sugar control" -> "Glycemic management").

[Video Context] {context_text if context_text else "N/A"}
[Authoritative KB Evidence] {kb_evidence if kb_evidence else "No direct evidence found in KB."}

[Critical Evaluation Rules]
1. Perform entity normalization before matching.
Treat semantically equivalent medical terms as the same entity.
Examples:
- "type 2 diabetes" = "type ii diabetes mellitus"
- "t2d" = "type 2 diabetes"
Only disregard KB if the subject is clearly unrelated.

2. When evaluating correctness:
- First attempt to match with KB evidence (if semantic alignment exists).
- If no relevant KB evidence is found, use established medical knowledge for judgment.

3. Only mark False if:
- The claim contradicts strong medical consensus, OR
- The claim contradicts reliable evidence, OR
- The claim is medically implausible or unsupported.

4. The relation "associated with" can describe:
- presence of a property
- absence of a property
Examples:
- associated with insulin resistance
- associated with absence of autoantibodies

5. Only treat KB evidence as contradiction if it refers to the SAME attribute or concept.
   If the KB discusses a different attribute, it should NOT be used to reject the claim.

[Task]
1. Status: Classify as "True" or "False".
   - "True": Claim is medically correct, supported by KB evidence or general medical knowledge.
   - "False": Claim directly contradicts a matching KB entry, established medical facts, or is medically implausible.

2. Explanation: Provide a concise reason for your decision, referencing KB match quality explicitly.
   - If Cosine Similarity < 0.6, you MUST identify a Mismatch Reason from:
     * Granularity Mismatch: Triple is too broad or too specific compared to KB.
     * Contextual Shift: Colloquial/metaphorical language drifted in vector space.
     * Logical Inversion: Predicate direction is reversed or negated.
     * Entity Ambiguity: Entity has multiple meanings causing vector drift.
     * Fact Contradiction: Directly contradicts evidence-based medicine.

Return ONLY a JSON object in this exact format:
{{"status": "True" or "False", "explanation": "...", "mismatch_reason": "Category name or null"}}
"""

    try:
        response = client.chat.completions.create(
            model="deepseek-chat",
            messages=[
                {"role": "system", "content": "You are a professional medical knowledge graph verifier. Always return valid JSON only."},
                {"role": "user", "content": prompt}
            ],
            response_format={"type": "json_object"},
            temperature=0,
            top_p=1
        )
        return json.loads(response.choices[0].message.content)

    except Exception as e:
        return {"status": "Error", "explanation": str(e), "mismatch_reason": None}

# --- Main Program ---
def main():
    print("Loading social media data...")
    social_data = load_json_data(SOCIAL_DATA_JSON)
    print("Total records:", len(social_data))

    final_report = []
    total_triplets = 0
    true_count = 0

    # ===== Group by Video =====
    grouped = defaultdict(list)
    for row in social_data:
        source = f"Video_{row.get('source_row', 'unknown')}"
        grouped[source].append(row)

    print("Total videos:", len(grouped))

    # ===== Main Loop =====
    for i, (source, triplets) in enumerate(grouped.items()):
        print(f"Processing {i+1}/{len(grouped)}: {source}")

        verified_triplets = []
        video_true = 0
        video_total = 0

        for t in triplets:
            target_vec = t.get('embedding')

            # Pass subject into retrieval for match quality check
            kb_match, similarity = get_best_kb_match(target_vec, t.get('subject', ''))

            if kb_match:
                kb_evidence = (
                    f"Subject: {kb_match.get('subject')} | "
                    f"Predicate: {kb_match.get('predicate')} | "
                    f"Object: {kb_match.get('object')} | "
                    f"Similarity: {similarity:.4f}"
                )
            else:
                kb_evidence = None

            verification = verify_with_llm_and_kb(t, "", kb_evidence, similarity)

            # Remove embedding from output
            t_clean = {k: v for k, v in t.items() if k != 'embedding'}
            t_clean.update(verification)

            if kb_match:
                t_clean['kb_alignment_info'] = {
                    "kb_subject": kb_match.get("subject"),
                    "kb_predicate": kb_match.get("predicate"),
                    "kb_object": kb_match.get("object"),
                    "similarity_score": similarity
                }
            else:
                t_clean['kb_alignment_info'] = {
                    "kb_subject": None,
                    "kb_predicate": None,
                    "kb_object": None,
                    "similarity_score": similarity
                }

            video_total += 1
            total_triplets += 1
            if str(verification.get("status", "")).strip().lower() == "true":
                video_true += 1
                true_count += 1

            verified_triplets.append(t_clean)

        video_accuracy = round(video_true / video_total, 4) if video_total > 0 else 0.0

        final_report.append({
            "video_source": source,
            "video_accuracy": video_accuracy,
            "video_true_count": video_true,
            "video_total_count": video_total,
            "verification_results": verified_triplets
        })

        time.sleep(0.05)

    # ===== Overall Accuracy =====
    overall_accuracy = round(true_count / total_triplets, 4) if total_triplets > 0 else 0.0

    output = {
        "overall_summary": {
            "total_triplets": total_triplets,
            "true_count": true_count,
            "false_count": total_triplets - true_count,
            "overall_accuracy": overall_accuracy
        },
        "video_reports": final_report
    }

    with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
        json.dump(output, f, ensure_ascii=False, indent=2)

    print("\n===== Verification Complete =====")
    print(f"Total triplets:     {total_triplets}")
    print(f"True count:         {true_count}")
    print(f"False count:        {total_triplets - true_count}")
    print(f"Overall accuracy:   {overall_accuracy:.2%}")
    print(f"Output file:        {OUTPUT_FILE}")

if __name__ == "__main__":
    main()
# Out:
# Loading authoritative knowledge base...
# KB matrix shape: (4940, 768)
# Loading social media data...
# Total records: 2803
# Total videos: 300
# Processing 1/300: Video_0
# Processing 2/300: Video_1
# Processing 3/300: Video_2
# Processing 4/300: Video_3
# Processing 5/300: Video_5
# Processing 6/300: Video_6
# Processing 7/300: Video_7
# Processing 8/300: Video_8
# Processing 9/300: Video_9
# Processing 10/300: Video_10
# Processing 11/300: Video_11
# Processing 12/300: Video_12
# Processing 13/300: Video_13
# Processing 14/300: Video_14
# Processing 15/300: Video_15
# Processing 16/300: Video_16
# Processing 17/300: Video_17
# Processing 18/300: Video_18
# Processing 19/300: Video_19
# Processing 20/300: Video_20
# Processing 21/300: Video_21
# Processing 22/300: Video_22
# Processing 23/300: Video_23
# Processing 24/300: Video_24
# Processing 25/300: Video_25
# Processing 26/300: Video_26
# Processing 27/300: Video_27
# Processing 28/300: Video_28
# Processing 29/300: Video_29
# Processing 30/300: Video_30
# Processing 31/300: Video_31
# Processing 32/300: Video_32
# Processing 33/300: Video_33
# Processing 34/300: Video_34
# Processing 35/300: Video_35
# Processing 36/300: Video_36
# Processing 37/300: Video_37
# Processing 38/300: Video_38
# Processing 39/300: Video_39
# Processing 40/300: Video_40
# Processing 41/300: Video_41
# Processing 42/300: Video_42
# Processing 43/300: Video_43
# Processing 44/300: Video_44
# Processing 45/300: Video_45
# Processing 46/300: Video_46
# Processing 47/300: Video_47
# Processing 48/300: Video_48
# Processing 49/300: Video_49
# Processing 50/300: Video_50
# Processing 51/300: Video_51
# Processing 52/300: Video_52
# Processing 53/300: Video_53
# Processing 54/300: Video_54
# Processing 55/300: Video_55
# Processing 56/300: Video_56
# Processing 57/300: Video_57
# Processing 58/300: Video_58
# Processing 59/300: Video_59
# Processing 60/300: Video_60
# Processing 61/300: Video_61
# Processing 62/300: Video_62
# Processing 63/300: Video_63
# Processing 64/300: Video_64
# Processing 65/300: Video_65
# Processing 66/300: Video_66
# Processing 67/300: Video_67
# Processing 68/300: Video_68
# Processing 69/300: Video_69
# Processing 70/300: Video_70
# Processing 71/300: Video_71
# Processing 72/300: Video_72
# Processing 73/300: Video_73
# Processing 74/300: Video_74
# Processing 75/300: Video_75
# Processing 76/300: Video_76
# Processing 77/300: Video_77
# Processing 78/300: Video_78
# Processing 79/300: Video_79
# Processing 80/300: Video_80
# Processing 81/300: Video_81
# Processing 82/300: Video_82
# Processing 83/300: Video_83
# Processing 84/300: Video_84
# Processing 85/300: Video_85
# Processing 86/300: Video_86
# Processing 87/300: Video_87
# Processing 88/300: Video_88
# Processing 89/300: Video_89
# Processing 90/300: Video_90
# Processing 91/300: Video_91
# Processing 92/300: Video_92
# Processing 93/300: Video_93
# Processing 94/300: Video_94
# Processing 95/300: Video_96
# Processing 96/300: Video_97
# Processing 97/300: Video_98
# Processing 98/300: Video_99
# Processing 99/300: Video_101
# Processing 100/300: Video_103
# Processing 101/300: Video_104
# Processing 102/300: Video_106
# Processing 103/300: Video_107
# Processing 104/300: Video_108
# Processing 105/300: Video_109
# Processing 106/300: Video_110
# Processing 107/300: Video_111
# Processing 108/300: Video_112
# Processing 109/300: Video_113
# Processing 110/300: Video_114
# Processing 111/300: Video_115
# Processing 112/300: Video_118
# Processing 113/300: Video_121
# Processing 114/300: Video_122
# Processing 115/300: Video_123
# Processing 116/300: Video_124
# Processing 117/300: Video_125
# Processing 118/300: Video_126
# Processing 119/300: Video_127
# Processing 120/300: Video_128
# Processing 121/300: Video_129
# Processing 122/300: Video_130
# Processing 123/300: Video_132
# Processing 124/300: Video_133
# Processing 125/300: Video_134
# Processing 126/300: Video_135
# Processing 127/300: Video_136
# Processing 128/300: Video_137
# Processing 129/300: Video_138
# Processing 130/300: Video_139
# Processing 131/300: Video_140
# Processing 132/300: Video_141
# Processing 133/300: Video_142
# Processing 134/300: Video_143
# Processing 135/300: Video_144
# Processing 136/300: Video_145
# Processing 137/300: Video_146
# Processing 138/300: Video_147
# Processing 139/300: Video_148
# Processing 140/300: Video_149
# Processing 141/300: Video_150
# Processing 142/300: Video_151
# Processing 143/300: Video_152
# Processing 144/300: Video_154
# Processing 145/300: Video_155
# Processing 146/300: Video_157
# Processing 147/300: Video_158
# Processing 148/300: Video_159
# Processing 149/300: Video_160
# Processing 150/300: Video_161
# Processing 151/300: Video_162
# Processing 152/300: Video_163
# Processing 153/300: Video_164
# Processing 154/300: Video_165
# Processing 155/300: Video_166
# Processing 156/300: Video_167
# Processing 157/300: Video_168
# Processing 158/300: Video_169
# Processing 159/300: Video_171
# Processing 160/300: Video_172
# Processing 161/300: Video_173
# Processing 162/300: Video_174
# Processing 163/300: Video_175
# Processing 164/300: Video_179
# Processing 165/300: Video_180
# Processing 166/300: Video_181
# Processing 167/300: Video_182
# Processing 168/300: Video_183
# Processing 169/300: Video_184
# Processing 170/300: Video_185
# Processing 171/300: Video_186
# Processing 172/300: Video_187
# Processing 173/300: Video_188
# Processing 174/300: Video_192
# Processing 175/300: Video_194
# Processing 176/300: Video_195
# Processing 177/300: Video_196
# Processing 178/300: Video_197
# Processing 179/300: Video_198
# Processing 180/300: Video_199
# Processing 181/300: Video_202
# Processing 182/300: Video_203
# Processing 183/300: Video_205
# Processing 184/300: Video_206
# Processing 185/300: Video_207
# Processing 186/300: Video_208
# Processing 187/300: Video_209
# Processing 188/300: Video_210
# Processing 189/300: Video_212
# Processing 190/300: Video_213
# Processing 191/300: Video_214
# Processing 192/300: Video_215
# Processing 193/300: Video_216
# Processing 194/300: Video_217
# Processing 195/300: Video_218
# Processing 196/300: Video_219
# Processing 197/300: Video_220
# Processing 198/300: Video_221
# Processing 199/300: Video_222
# Processing 200/300: Video_223
# Processing 201/300: Video_224
# Processing 202/300: Video_225
# Processing 203/300: Video_226
# Processing 204/300: Video_227
# Processing 205/300: Video_228
# Processing 206/300: Video_229
# Processing 207/300: Video_230
# Processing 208/300: Video_232
# Processing 209/300: Video_233
# Processing 210/300: Video_234
# Processing 211/300: Video_235
# Processing 212/300: Video_236
# Processing 213/300: Video_237
# Processing 214/300: Video_238
# Processing 215/300: Video_239
# Processing 216/300: Video_240
# Processing 217/300: Video_241
# Processing 218/300: Video_242
# Processing 219/300: Video_243
# Processing 220/300: Video_245
# Processing 221/300: Video_246
# Processing 222/300: Video_248
# Processing 223/300: Video_249
# Processing 224/300: Video_250
# Processing 225/300: Video_251
# Processing 226/300: Video_252
# Processing 227/300: Video_253
# Processing 228/300: Video_254
# Processing 229/300: Video_256
# Processing 230/300: Video_257
# Processing 231/300: Video_258
# Processing 232/300: Video_259
# Processing 233/300: Video_260
# Processing 234/300: Video_261
# Processing 235/300: Video_262
# Processing 236/300: Video_263
# Processing 237/300: Video_264
# Processing 238/300: Video_265
# Processing 239/300: Video_266
# Processing 240/300: Video_267
# Processing 241/300: Video_268
# Processing 242/300: Video_269
# Processing 243/300: Video_270
# Processing 244/300: Video_273
# Processing 245/300: Video_274
# Processing 246/300: Video_275
# Processing 247/300: Video_276
# Processing 248/300: Video_277
# Processing 249/300: Video_278
# Processing 250/300: Video_279
# Processing 251/300: Video_280
# Processing 252/300: Video_281
# Processing 253/300: Video_282
# Processing 254/300: Video_283
# Processing 255/300: Video_284
# Processing 256/300: Video_285
# Processing 257/300: Video_286
# Processing 258/300: Video_287
# Processing 259/300: Video_288
# Processing 260/300: Video_289
# Processing 261/300: Video_290
# Processing 262/300: Video_291
# Processing 263/300: Video_292
# Processing 264/300: Video_293
# Processing 265/300: Video_294
# Processing 266/300: Video_295
# Processing 267/300: Video_296
# Processing 268/300: Video_297
# Processing 269/300: Video_298
# Processing 270/300: Video_299
# Processing 271/300: Video_300
# Processing 272/300: Video_301
# Processing 273/300: Video_302
# Processing 274/300: Video_303
# Processing 275/300: Video_304
# Processing 276/300: Video_305
# Processing 277/300: Video_306
# Processing 278/300: Video_307
# Processing 279/300: Video_308
# Processing 280/300: Video_309
# Processing 281/300: Video_310
# Processing 282/300: Video_311
# Processing 283/300: Video_312
# Processing 284/300: Video_313
# Processing 285/300: Video_314
# Processing 286/300: Video_315
# Processing 287/300: Video_316
# Processing 288/300: Video_317
# Processing 289/300: Video_318
# Processing 290/300: Video_319
# Processing 291/300: Video_320
# Processing 292/300: Video_321
# Processing 293/300: Video_322
# Processing 294/300: Video_323
# Processing 295/300: Video_324
# Processing 296/300: Video_325
# Processing 297/300: Video_326
# Processing 298/300: Video_327
# Processing 299/300: Video_328
# Processing 300/300: Video_329
#
# ===== Verification Complete =====
# Total triplets:     2803
# True count:         2069
# False count:        734
# Overall accuracy:   73.81%
# Output file:        newresult/triples_ver2_result2.json
